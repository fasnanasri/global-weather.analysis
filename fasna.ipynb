# %%
a=[10,20,30,40,50]
i=0
while i<len(a):
      print(a[i])
      i+=1
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
a=[1,2,3,4,5,6]
for x in a:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
a=[9,8,7,6]
a.remove(6)
print(a)
# Out:
# [9, 8, 7]

# %%
a=[1,2,3,5]
a.pop()
print(a)
# Out:
# [1, 2, 3]

# %%
a=[200,300,400]
print(a.index(300))
print(a.index(400))
print(a.index(200))
# Out:
# 1
# 2
# 0

# %%
a=[1,3,4,4,4,5,6]
set(a)
# Out:
# {1, 3, 4, 5, 6}

# %%
a=[2,4,3,7,9]
a.clear()
print(a)
# Out:
# []

# %%
import pandas as pd

# %%
df=pd.read_csv("GlobalWeatherRepository - GlobalWeatherRepository (1).csv")

# %%
df.iloc[5:10]
# Out:
#                country location_name  latitude  longitude  \
# 5  Antigua and Barbuda  Saint John's     17.12     -61.85
# 6            Argentina  Buenos Aires    -34.59     -58.67
# 7              Armenia       Yerevan     40.18      44.51
# 8            Australia      Canberra    -35.28     149.22
# 9              Austria        Vienna     48.20      16.37
#
#                          timezone  last_updated_epoch      last_updated  \
# 5                 America/Antigua          1715849100  2024-05-16 04:45
# 6  America/Argentina/Buenos_Aires          1715849100  2024-05-16 05:45
# 7                    Asia/Yerevan          1715849100  2024-05-16 12:45
# 8                Australia/Sydney          1715849100  2024-05-16 18:45
# 9                   Europe/Vienna          1715849100  2024-05-16 10:45
#
#    temperature_celsius  temperature_fahrenheit condition_text  ...  \
# 5                 26.0                    78.8  Partly cloudy  ...
# ...

# %%
import pandas as pd

# %%
df[df["latitude"]>10]
# Out:
#                          country      location_name  latitude  longitude  \
# 0                    Afghanistan              Kabul   34.5200    69.1800
# 1                        Albania             Tirana   41.3300    19.8200
# 2                        Algeria            Algiers   36.7600     3.0500
# 3                        Andorra   Andorra La Vella   42.5000     1.5200
# 5            Antigua and Barbuda       Saint John's   17.1200   -61.8500
# ...                          ...                ...       ...        ...
# 135064  United States of America  Washington Harbor   48.0792  -123.0439
# 135066                Uzbekistan           Tashkent   41.3167    69.2500
# 135068                 Venezuela            Caracas   10.5000   -66.9167
# 135069                   Vietnam              Hanoi   21.0333   105.8500
# 135070                     Yemen              Sanaa   15.3547    44.2067
#
#                    timezone  last_updated_epoch      last_updated  \
# ...

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.tail()
# Out:
#           country location_name  latitude  longitude         timezone  \
# 135068  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 135069    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 135071     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 135068          1775975400  2026-04-12 02:30                 19.1
# 135069          1775975400  2026-04-12 13:30                 34.2
# 135070          1775975400  2026-04-12 09:30                 19.3
# 135071          1775975400  2026-04-12 08:30                 18.5
# 135072          1775975400  2026-04-12 08:30                 17.4
#
#         temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 135068                    66.3  Partly Cloudy  ...              16.35
# ...

# %%
df.sample(3)
# Out:
#               country location_name  latitude  longitude        timezone  \
# 90266  Czech Republic        Prague   50.0833    14.4667   Europe/Prague
# 26819        Bulgaria         Bogot   43.3200    24.7000    Europe/Sofia
# 37466          Belize      Belmopan   17.2500   -88.7667  America/Belize
#
#        last_updated_epoch      last_updated  temperature_celsius  \
# 90266          1756022400  2025-08-24 10:00                 14.0
# 26819          1727861400  2024-10-02 12:30                 18.8
# 37466          1732610700  2024-11-26 02:45                 19.9
#
#        temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 90266                    57.2          Sunny  ...              7.955
# 26819                    65.9          Sunny  ...             10.730
# 37466                    67.7            Fog  ...             10.545
#
#        air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# ...

# %%
df.shape
# Out:
# (135073, 41)

# %%
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135073 entries, 0 to 135072
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       135073 non-null  object
#  1   location_name                 135073 non-null  object
#  2   latitude                      135073 non-null  float64
#  3   longitude                     135073 non-null  float64
#  4   timezone                      135073 non-null  object
#  5   last_updated_epoch            135073 non-null  int64
#  6   last_updated                  135073 non-null  object
#  7   temperature_celsius           135073 non-null  float64
#  8   temperature_fahrenheit        135073 non-null  float64
#  9   condition_text                135073 non-null  object
#  10  wind_mph                      135073 non-null  float64
#  11  wind_kph                      135073 non-null  float64
# ...

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
a=[6,3,9,1]
print(len(a))
print(max(a))
print(min(a))
print(sum(a))
print(sorted(a))
# Out:
# 4
# 9
# 1
# 19
# [1, 3, 6, 9]

# %%
a=[1,2,3]
a.reverse()
print(a)
# Out:
# [3, 2, 1]

# %%
e=[3,1,2]
print(sorted(e))
# Out:
# [1, 2, 3]

# %%
d=[10,20,30]
print(sum(d))
# Out:
# 60

# %%
c=[5,2,8]
print(min(c))
# Out:
# 2

# %%
b=[5,7,9]
print(max(b))
# Out:
# 9

# %%
df[(df["latitude"]>10) & (df["latitude"]<50)]
# Out:
#                          country      location_name  latitude  longitude  \
# 0                    Afghanistan              Kabul   34.5200    69.1800
# 1                        Albania             Tirana   41.3300    19.8200
# 2                        Algeria            Algiers   36.7600     3.0500
# 3                        Andorra   Andorra La Vella   42.5000     1.5200
# 5            Antigua and Barbuda       Saint John's   17.1200   -61.8500
# ...                          ...                ...       ...        ...
# 135064  United States of America  Washington Harbor   48.0792  -123.0439
# 135066                Uzbekistan           Tashkent   41.3167    69.2500
# 135068                 Venezuela            Caracas   10.5000   -66.9167
# 135069                   Vietnam              Hanoi   21.0333   105.8500
# 135070                     Yemen              Sanaa   15.3547    44.2067
#
#                    timezone  last_updated_epoch      last_updated  \
# ...

# %%
df[(df["latitude"]>10) | (df["latitude"]<50)]
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
a=[1,2,3]
print(len(a))
# Out:
# 3

# %%
df[["longitude","latitude"]]=df["timezone"].str.split("/", expand = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df[["longitude","latitude"]]=df["timezone"].str.split("/", expand = True)
#
# NameError: name 'df' is not defined

# %%
df["test1"]=df[]
# Out:
#   Cell In[1], line 1
#     df["test1"]=df[]
#                    ^
# SyntaxError: invalid syntax

# %%
df["latitude"].value_counts()
# Out:
# latitude
#  41.90    833
#  40.40    832
#  12.15    830
#  5.55     695
#  3.75     695
#          ...
#  39.53      1
#  4.60       1
#  4.05       1
# -4.05       1
#  59.89      1
# Name: count, Length: 397, dtype: int64

# %%
df["latitude"].mean()
# Out:
# np.float64(19.208948125087915)

# %%
df["longitude"].median()
# Out:
# 23.2361

# %%
df["latitude"].max()
# Out:
# 64.15

# %%
df["longitude"].min()
# Out:
# -175.2

# %%
df["latitude"].mode()
# Out:
# 0    41.9
# Name: latitude, dtype: float64

# %%
df[df["country"]=="India"]
# Out:
#        country location_name  latitude  longitude      timezone  \
# 77       India     New Delhi      28.6       77.2  Asia/Kolkata
# 272      India     New Delhi      28.6       77.2  Asia/Kolkata
# 467      India     New Delhi      28.6       77.2  Asia/Kolkata
# 659      India     New Delhi      28.6       77.2  Asia/Kolkata
# 853      India     New Delhi      28.6       77.2  Asia/Kolkata
# ...        ...           ...       ...        ...           ...
# 134175   India     New Delhi      28.6       77.2  Asia/Kolkata
# 134370   India     New Delhi      28.6       77.2  Asia/Kolkata
# 134565   India     New Delhi      28.6       77.2  Asia/Kolkata
# 134760   India     New Delhi      28.6       77.2  Asia/Kolkata
# 134955   India     New Delhi      28.6       77.2  Asia/Kolkata
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 77              1715849100  2024-05-16 14:15                 42.0
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
df.isnull()
# Out:
#         country  location_name  latitude  longitude  timezone  \
# 0         False          False     False      False     False
# 1         False          False     False      False     False
# 2         False          False     False      False     False
# 3         False          False     False      False     False
# 4         False          False     False      False     False
# ...         ...            ...       ...        ...       ...
# 135068    False          False     False      False     False
# 135069    False          False     False      False     False
# 135070    False          False     False      False     False
# 135071    False          False     False      False     False
# 135072    False          False     False      False     False
#
#         last_updated_epoch  last_updated  temperature_celsius  \
# 0                    False         False                False
# 1                    False         False                False
# ...

# %%
df.shape
# Out:
# (135073, 41)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated_epoch, last_updated, temperature_celsius, temperature_fahrenheit, condition_text, wind_mph, wind_kph, wind_degree, wind_direction, pressure_mb, pressure_in, precip_mm, precip_in, humidity, cloud, feels_like_celsius, feels_like_fahrenheit, visibility_km, visibility_miles, uv_index, gust_mph, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 41 columns]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, location_name, latitude, longitude, timezone, last_updated_epoch, last_updated, temperature_celsius, temperature_fahrenheit, condition_text, wind_mph, wind_kph, wind_degree, wind_direction, pressure_mb, pressure_in, precip_mm, precip_in, humidity, cloud, feels_like_celsius, feels_like_fahrenheit, visibility_km, visibility_miles, uv_index, gust_mph, gust_kph, air_quality_Carbon_Monoxide, air_quality_Ozone, air_quality_Nitrogen_dioxide, air_quality_Sulphur_dioxide, air_quality_PM2.5, air_quality_PM10, air_quality_us-epa-index, air_quality_gb-defra-index, sunrise, sunset, moonrise, moonset, moon_phase, moon_illumination]
# Index: []
#
# [0 rows x 41 columns]

# %%
df.sort_values(by="latitude")
# Out:
#             country location_name  latitude  longitude            timezone  \
# 101262  New Zealand    Wellington    -41.30   174.7833    Pacific/Auckland
# 12891   New Zealand    Wellington    -41.30   174.7800    Pacific/Auckland
# 24760   New Zealand    Wellington    -41.30   174.7800    Pacific/Auckland
# 94439   New Zealand    Wellington    -41.30   174.7833    Pacific/Auckland
# 115496  New Zealand    Wellington    -41.30   174.7833    Pacific/Auckland
# ...             ...           ...       ...        ...                 ...
# 128909      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 91663       Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 131249      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 104334      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 126942      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
df=df.drop_duplicates()

# %%
df=df.dropna(subset=["latitude"])

# %%
df["latitude"] =df["latitude"].fillna(0)

# %%
df["latitude"] =df["latitude"].fillna("")

# %%
df["latitude"]=df["latitude"].ffill()
df["latitude"]=df["latitude"].bfill()

# %%
df["country"].str.lower()
# Out:
# 0         afghanistan
# 1             albania
# 2             algeria
# 3             andorra
# 4              angola
#              ...
# 135068      venezuela
# 135069        vietnam
# 135070          yemen
# 135071         zambia
# 135072       zimbabwe
# Name: country, Length: 135073, dtype: object

# %%
df["country"].str.upper()
# Out:
# 0         AFGHANISTAN
# 1             ALBANIA
# 2             ALGERIA
# 3             ANDORRA
# 4              ANGOLA
#              ...
# 135068      VENEZUELA
# 135069        VIETNAM
# 135070          YEMEN
# 135071         ZAMBIA
# 135072       ZIMBABWE
# Name: country, Length: 135073, dtype: object
